# %% [markdown]
# ## Morphology locations as a Form
#
# This is probably not very useful. Morphology locations are a rather abstract concept.
# The form simply plots the generate locations on the morphology and writes them to a csv file.

# %%
import obi_one as obi
from pathlib import Path

morph_path = Path("data/morphologies/L5_TPC:A_MusMusculus_PrimarySomatosensory_C060114A5/C060114A5.swc")

# %%
morph_locations = obi.RandomMorphologyLocations(number_of_locations=[10, 20], section_types=(4, ))
# Try this one for a more exciting example.
# morph_locations = obi.ClusteredPathDistanceMorphologyLocations(
#                         number_of_locations=[100, 200],
#                         section_types=(4, ),
#                         n_clusters=10,
#                         cluster_max_distance=20,
#                         path_dist_mean=200,
#                         path_dist_sd=80,
#                         n_groups_per_cluster=2,
#                     )
morph_loc_form = obi.MorphologyLocationsForm(
                    initialize=obi.MorphologyLocations.Initialize(
                        morphology=[morph_path]
                    ),
                    morph_locations=morph_locations
)

grid_scan = obi.GridScan(form=morph_loc_form, output_root="../../obi-output/morphology_locations")
grid_scan.execute(processing_method="run")
# Out:
# [2025-05-30 10:07:27,888] INFO: create_bbp_workflow_campaign_config() not yet complete.
# {0: None, 1: None}

# %% [markdown]
# ## Morphology locations blocks
#
# There are several blocks of differing complexity that generate locations. Above, we used the simplest one, but others are available.
#
# Here, we demo most of them.

# %%
from morphio import Morphology as MorphioMorphology
m = MorphioMorphology(morph_path)

# %% [markdown]
# ### RandomMorphologyLocations
# Simplest case: Random locations without constraints.
#
# Note that there are no constraints on path distance or anything, really.

# %%
# Default number of locations is 1
tst = obi.RandomMorphologyLocations()
display(tst.points_on(m))

# Can specify a larger number instead.
tst = obi.RandomMorphologyLocations(number_of_locations=10)
display(tst.points_on(m))

# Can also limit the section types.
# Note that the above likely has different section types, this one only shows "4".
tst = obi.RandomMorphologyLocations(number_of_locations=10, section_types=(4, ))
display(tst.points_on(m))
# Out:
#    segment_id  section_id  section_type  segment_offset  path_distance  \
# 0          13         169             2        1.717101     447.357938
#
#    source_index  normalized_section_offset
# 0             0                   0.639919
#    segment_id  section_id  section_type  segment_offset  path_distance  \
# 0         121         126             2        1.900856     571.989530
# 1          39         141             2        1.353891     332.392681
# 2           4         144             2        1.735432     556.837090
# 3          57         168             2        1.581673     361.602878
# 4          13         169             2        0.163442     447.357938
# 5           8         199             3        0.125681      41.593017
# 6          21         222             3        0.059699      37.054228
# 7           6         254             3        1.606591      37.121108
# 8          13         328             4        3.391054     275.199254
# 9          30         358             4        2.823483     126.999160
#
#    source_index  normalized_section_offset
# 0             0                   0.854157
# 1             0                   0.852600
# 2             0                   0.054285
# 3             0                   0.647452
# 4             0                   0.639919
# 5             0                   0.258579
# 6             0                   0.778710
# 7             0                   0.099668
# 8             0                   0.821467
# 9             0                   0.556715
#    segment_id  section_id  section_type  segment_offset  path_distance  \
# 0           3         304             4        1.932028     553.429249
# 1           1         309             4        1.375812     641.342161
# 2          10         310             4        1.283931     655.756402
# 3          96         319             4        2.945596     740.790337
# 4         108         319             4        0.139708     765.267371
# 5           0         326             4        0.246460     210.808930
# 6          34         332             4        0.031643     239.926013
# 7          35         340             4        1.732307     213.000368
# 8          11         361             4        1.415862      75.361434
# 9           1         371             4        2.568509       4.367881
#
#    source_index  normalized_section_offset
# 0             0                   0.120972
# 1             0                   0.032926
# 2             0                   0.815279
# 3             0                   0.813551
# 4             0                   0.939105
# 5             0                   0.000000
# 6             0                   0.607566
# 7             0                   0.784221
# 8             0                   0.228948
# 9             0                   0.558705

# %% [markdown]
# ### RandomGroupedMorphologyLocations
# This only adds a grouping to the output. That is, the column "source_index" can have values other than 0.

# %%
# Default is a single group. This does not change anything.
tst = obi.RandomGroupedMorphologyLocations()
display(tst.points_on(m))

# More customized. Now "source_index" has different values
tst = obi.RandomGroupedMorphologyLocations(number_of_locations=10, n_groups=2)
display(tst.points_on(m))
# Out:
#    segment_id  section_id  section_type  segment_offset  path_distance  \
# 0          13         169             2        1.717101     447.357938
#
#    source_index  normalized_section_offset
# 0             0                   0.639919
#    segment_id  section_id  section_type  segment_offset  path_distance  \
# 0         121         126             2        1.900856     571.989530
# 1          39         141             2        1.353891     332.392681
# 2           4         144             2        1.735432     556.837090
# 3          57         168             2        1.581673     361.602878
# 4          13         169             2        0.163442     447.357938
# 5           8         199             3        0.125681      41.593017
# 6          21         222             3        0.059699      37.054228
# 7           6         254             3        1.606591      37.121108
# 8          13         328             4        3.391054     275.199254
# 9          30         358             4        2.823483     126.999160
#
#    source_index  normalized_section_offset
# 0             0                   0.854157
# 1             1                   0.852600
# 2             0                   0.054285
# 3             1                   0.647452
# 4             1                   0.639919
# 5             1                   0.258579
# 6             1                   0.778710
# 7             1                   0.099668
# 8             0                   0.821467
# 9             1                   0.556715

# %% [markdown]
# ### ClusteredMorphologyLocations
# This constrains generated locations such that they are clustered. That means, groups of them will be within a specified maximum distance of each other. Note that this distance is two times the value of the parameter 'cluster_max_distance'.

# %%
# Note that many locations will be on the same section and nearby segments.
tst = obi.ClusteredMorphologyLocations(number_of_locations=20, n_clusters=5, cluster_max_distance=5.0)
display(tst.points_on(m))

# Also section type can always be specified.
tst = obi.ClusteredMorphologyLocations(number_of_locations=20, n_clusters=5,
                                       cluster_max_distance=5.0, section_types=(3,))
display(tst.points_on(m))
# Out:
#     segment_id  section_id  section_type  segment_offset  path_distance  \
# 0           32         186             3        0.877714     124.463259
# 1           33         186             3        1.919091     126.819746
# 2           33         186             3        1.210663     126.819746
# 3           34         186             3        0.304689     128.232456
# 4            4         266             4        2.455485     185.013322
# 5            5         266             4        2.309554     188.104051
# 6            5         266             4        2.582179     188.104051
# 7            0         329             4        3.207534     191.062594
# 8           10         217             3        1.592915      57.489186
# 9           11         217             3        0.412682      60.120405
# 10          12         217             3        2.351505      62.804410
# 11          12         217             3        1.243910      62.804410
# 12          23         185             3        0.871712      42.556493
# 13          24         185             3        0.005710      43.475205
# 14          25         185             3        1.684111      45.055985
# 15          27         185             3        0.996510      47.266461
# 16          29         145             2        1.206787     615.112922
# 17          31         145             2        1.522554     617.572384
# 18          31         145             2        0.166302     617.572384
# 19          33         145             2        1.412124     620.057527
#
#     source_index  normalized_section_offset
# 0              0                   0.922827
# 1              0                   0.958462
# 2              0                   0.958462
# 3              0                   0.992114
# 4              1                   0.659211
# 5              1                   0.836373
# 6              1                   0.836373
# 7              1                   0.000000
# 8              2                   0.158271
# 9              2                   0.182466
# 10             2                   0.211686
# 11             2                   0.211686
# 12             3                   0.630470
# 13             3                   0.636683
# 14             3                   0.668034
# 15             3                   0.701993
# 16             4                   0.423939
# 17             4                   0.437289
# 18             4                   0.437289
# 19             4                   0.454616
#     segment_id  section_id  section_type  segment_offset  path_distance  \
# 0            7         224             3        0.603152      57.548093
# 1            9         224             3        1.382524      59.220944
# 2           11         224             3        0.703051      63.581738
# 3           11         224             3        0.755092      63.581738
# 4           11         238             3        1.730516      59.183707
# 5           11         238             3        2.019573      59.183707
# 6           11         238             3        2.201303      59.183707
# 7           15         238             3        2.416174      66.774733
# 8            0         229             3        1.744547      10.527065
# 9            2         229             3        0.196394      14.579744
# 10           4         229             3        2.575348      18.095162
# 11           4         229             3        0.916622      18.095162
# 12          25         222             3        1.208465      45.246536
# 13           1         223             3        0.053040      49.290357
# 14           1         223             3        1.425175      49.290357
# 15           1         224             3        1.301288      49.787053
# 16          48         217             3        0.769499     135.809089
# 17          50         217             3        1.228346     138.112822
# 18          50         217             3        0.106041     138.112822
# 19          50         217             3        1.492857     138.112822
#
#     source_index  normalized_section_offset
# 0              0                   0.132768
# 1              0                   0.156088
# 2              0                   0.204653
# 3              0                   0.204653
# 4              1                   0.226096
# 5              1                   0.226096
# 6              1                   0.226096
# 7              1                   0.339280
# 8              2                   0.000000
# 9              2                   0.371845
# 10             2                   0.620329
# 11             2                   0.620329
# 12             3                   0.939499
# 13             3                   0.022716
# 14             3                   0.022716
# 15             3                   0.026182
# 16             4                   0.953966
# 17             4                   0.979776
# 18             4                   0.979776
# 19             4                   0.979776

# %% [markdown]
# ### ClusteredPathDistanceMorphologyLocations
# This exposes the full complexity: Several clusters at specific path distances, and several groups per cluster.

# %%
tst = obi.ClusteredPathDistanceMorphologyLocations(
    number_of_locations=100,
    n_clusters=5,
    cluster_max_distance=10.0,
    path_dist_mean=100.0,
    path_dist_sd=2.0
)
display(tst.points_on(m))
# Out:
#     reference_loc_index  segment_id  section_id  section_type  segment_offset  \
# 0                     0          40         246             3        1.245280
# 1                     0          40         246             3        0.242063
# 2                     0          40         246             3        2.396422
# 3                     0          42         246             3        0.692876
# 4                     0          47         246             3        0.700187
# ..                  ...         ...         ...           ...             ...
# 95                    4          36         238             3        0.990326
# 96                    4          36         238             3        1.678552
# 97                    4          38         238             3        0.910579
# 98                    4          38         238             3        0.570457
# 99                    4          38         238             3        0.072189
#
#     path_distance  source_index  normalized_section_offset
# 0       90.709366             0                   0.524390
# 1       90.709366             0                   0.524390
# 2       90.709366             0                   0.524390
# 3       92.835898             0                   0.545095
# 4       98.358747             0                   0.596748
# ..            ...           ...                        ...
# 95     104.795611             4                   0.890393
# 96     104.795611             4                   0.890393
# 97     107.444342             4                   0.924708
# 98     107.444342             4                   0.924708
# 99     107.444342             4                   0.924708
#
# [100 rows x 8 columns]
