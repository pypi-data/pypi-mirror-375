# %% [markdown]
# # 第三章：极化码进阶

# %% [markdown]
# 在这一章会讲一些我自己研究过程中曾精读、并复现过的极化码相关工作。
#
# 注意，这些相关工作无一例外地都触及了极化码和极化现象的本质，因此在叙述过程中，会出现一些非常高级的理论描述与技术术语。请确保你理解了前面所讲内容的基础上，再来看这一章节。
#
# 如果你是极化码资深的研究者，这一章节可以为你提供一些非理论化的、直观的方案复现效果，可以用于帮助你加深对经典工作的理解，甚至支撑你开发属于自己的极化编译码技术。
